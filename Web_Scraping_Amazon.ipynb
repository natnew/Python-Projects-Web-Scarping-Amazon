# %% [markdown]
# <a href="https://colab.research.google.com/github/natnew/Python-Projects-Web-Scarping-Amazon/blob/main/Web_Scraping_Amazon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Beautiful Soup Library

# %%
# !pip3 install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %% [markdown]
# # Install All Other Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Scarpe Amazon for Best Selling Books

# %%
no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'a-section a-spacing-none aok-relative'}):
        #print(d)
        name = d.find('span', attrs={'class':'zg-text-center-align'})
        n = name.find_all('img', alt=True)
        #print(n[0]['alt'])
        author = d.find('a', attrs={'class':'a-size-small a-link-child'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('a', attrs={'class':'a-size-small a-link-normal'})
        price = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(n[0]['alt'])
        else:
            all1.append("unknown-product")

        if author is not None:
            #print(author.text)
            all1.append(author.text)
        elif author is None:
            author = d.find('span', attrs={'class':'a-size-small a-color-base'})
            if author is not None:
                all1.append(author.text)
            else:    
                all1.append('0')

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')

        if users_rated is not None:
            #print(price.text)
            all1.append(users_rated.text)
        else:
            all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

# %% [markdown]
# #Write to a CSV File and Save it

# %%
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Book Name','Author','Rating','Customers_Rated', 'Price'])
df.to_csv('amazon_products.csv', index=False, encoding='utf-8')

# %% [markdown]
# #Read the CSV file

# %%
df = pd.read_csv("amazon_products.csv")

# %%
df.shape
# Out:
# (50, 5)

# %%
df.head(61)
# Out:
#                                             Book Name  ...    Price
# 0                                        DO EPIC SHIT  ...  ₹310.00
# 1   Atomic Habits: The life-changing million copy ...  ...  ₹482.00
# 2                             The Psychology of Money  ...  ₹301.00
# 3   Ikigai: The Japanese secret to a long and happ...  ...  ₹313.00
# 4                                Word Power Made Easy  ...   ₹92.00
# 5   Grandma's Bag of Stories: Collection of 20+ Il...  ...  ₹186.00
# 6   Rich Dad Poor Dad: What the Rich Teach Their K...  ...  ₹302.00
# 7   My First Library: Boxset of 10 Board Books for...  ...  ₹399.00
# 8   Life's Amazing Secrets: How to Find Balance an...  ...  ₹165.00
# 9   World’s Greatest Books For Personal Growth & W...  ...  ₹299.00
# 10  The Almanack Of Naval Ravikant: A Guide to Wea...  ...  ₹195.00
# 11                                           400 Days  ...  ₹169.00
# 12                                      The Alchemist  ...  ₹228.00
# 13                           It Ends With Us: A Novel  ...  ₹195.00
# 14  27 Years UPSC IAS/ IPS Prelims Topic-wise Solv...  ...  ₹305.00
# 15                The Power of Your Subconscious Mind  ...  ₹125.00
# 16  The Subtle Art of Not Giving a F*ck: A Counter...  ...  ₹325.00
# 17                                  As a Man Thinketh  ...   ₹59.00
# 18  Quantitative Aptitude for Competitive Examinat...  ...  ₹469.00
# 19  Attitude Is Everything: Change Your Attitude ....  ...  ₹149.00
# 20  My First Mythology Tale (Illustrated) (Set of ...  ...  ₹191.00
# 21  Rich Dad Poor Dad - 20Th Anniversary Edition -...  ...  ₹192.00
# 22              Sapiens: A Brief History of Humankind  ...  ₹372.00
# 23  The Intelligent Investor (English) Paperback –...  ...  ₹485.00
# 24  Eat That Frog!: 21 Great Ways to Stop Procrast...  ...  ₹146.00
# 25  Karma: A Yogi's Guide to Crafting Your Destiny...  ...  ₹148.00
# 26  My First Book of Pencil Control : Practice Pat...  ...   ₹89.00
# 27  Picture Books Collection for Early Learning (S...  ...  ₹240.00
# 28                       Grandparents' Bag of Stories  ...  ₹140.00
# 29                                  General Knowledge  ...  ₹170.00
# 30  Tirumala Tirupati Devasthanams Tirupati 130 GS...  ...  ₹315.00
# 31  MTG Objective NCERT at your FINGERTIPS - Biolo...  ...  ₹599.00
# 32  Indian Polity - For Civil Services and Other S...  ...  ₹608.00
# 33            How to Win Friends and Influence People  ...   ₹78.00
# 34                     Spoken English Course (Telugu)  ...  ₹299.00
# 35           Harry Potter and the Philosopher's Stone  ...  ₹298.00
# 36           Very First Sight Words Sentences Level 1  ...  ₹140.00
# 37  Brijbhoomi Books And Handicrafts® Bhagavad Git...  ...  ₹362.00
# 38  Moral Story Books for Kids (Pack of 10 Books) ...  ...  ₹225.00
# 39  Man's Search For Meaning: The classic tribute ...  ...  ₹237.00
# 40  Oswaal CBSE Question Bank Chapterwise For Term...  ...  ₹775.00
# 41  My Life in Full: Work, Family, and Our Future ...  ...  ₹471.00
# 42                     Manorama English Yearbook 2022  ...  ₹278.00
# 43                          The Diary of a Young Girl  ...   ₹99.00
# 44                         The Richest Man in Babylon  ...   ₹99.00
# 45  Think Like a Monk: The secret of how to harnes...  ...  ₹325.00
# 46                         Great Stories for Children  ...  ₹122.00
# 47  Death; An Inside Story: A book for all those w...  ...  ₹148.00
# 48                                  Wuthering Heights  ...   ₹99.00
# 49  101 Panchatantra Stories for Children: Colourf...  ...  ₹135.00
#
# [50 rows x 5 columns]

# %% [markdown]
# #Convert Columns to and integer or float

# %%
df['Rating'] = df['Rating'].apply(lambda x: x.split()[0])

# %%
df['Rating'] = pd.to_numeric(df['Rating'])

# %%
df["Price"] = df["Price"].str.replace('₹', '')

# %%
df["Price"] = df["Price"].str.replace(',', '')

# %%
df['Price'] = df['Price'].apply(lambda x: x.split('.')[0])

# %%
df['Price'] = df['Price'].astype(int)

# %%
df["Customers_Rated"] = df["Customers_Rated"].str.replace(',', '')

# %%
df['Customers_Rated'] = pd.to_numeric(df['Customers_Rated'], errors='ignore')

# %%
df.head()
# Out:
#                                            Book Name  ... Price
# 0                                       DO EPIC SHIT  ...   310
# 1  Atomic Habits: The life-changing million copy ...  ...   482
# 2                            The Psychology of Money  ...   301
# 3  Ikigai: The Japanese secret to a long and happ...  ...   313
# 4                               Word Power Made Easy  ...    92
#
# [5 rows x 5 columns]

# %% [markdown]
# #Verify the data types

# %%
df.dtypes
# Out:
# Book Name           object
# Author              object
# Rating             float64
# Customers_Rated      int64
# Price                int64
# dtype: object

# %% [markdown]
# #Replace zeros with NAN

# %%
df.replace(str(0), np.nan, inplace=True)
df.replace(0, np.nan, inplace=True)

# %% [markdown]
# #Count the number of NANs in the dataframe

# %%
count_nan = len(df) - df.count()

# %%
count_nan
# Out:
# Book Name          0
# Author             0
# Rating             0
# Customers_Rated    2
# Price              0
# dtype: int64

# %% [markdown]
# #Drop the NaN values

# %%
df = df.dropna()

# %% [markdown]
# #Find the highest priced book

# %%
data = df.sort_values(["Price"], axis=0, ascending=False)[:15]

# %%
data
# Out:
#                                             Book Name  ... Price
# 40  Oswaal CBSE Question Bank Chapterwise For Term...  ...   775
# 32  Indian Polity - For Civil Services and Other S...  ...   608
# 31  MTG Objective NCERT at your FINGERTIPS - Biolo...  ...   599
# 23  The Intelligent Investor (English) Paperback –...  ...   485
# 1   Atomic Habits: The life-changing million copy ...  ...   482
# 41  My Life in Full: Work, Family, and Our Future ...  ...   471
# 18  Quantitative Aptitude for Competitive Examinat...  ...   469
# 7   My First Library: Boxset of 10 Board Books for...  ...   399
# 22              Sapiens: A Brief History of Humankind  ...   372
# 37  Brijbhoomi Books And Handicrafts® Bhagavad Git...  ...   362
# 45  Think Like a Monk: The secret of how to harnes...  ...   325
# 16  The Subtle Art of Not Giving a F*ck: A Counter...  ...   325
# 30  Tirumala Tirupati Devasthanams Tirupati 130 GS...  ...   315
# 3   Ikigai: The Japanese secret to a long and happ...  ...   313
# 14  27 Years UPSC IAS/ IPS Prelims Topic-wise Solv...  ...   305
#
# [15 rows x 5 columns]

# %%
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
import math
from bokeh.io import curdoc
curdoc().clear()
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.models import Legend
output_notebook()

# %%
p = figure(x_range=data.iloc[:,1], plot_width=800, plot_height=550, title="Authors Highest Priced Book", toolbar_location=None, tools="")

p.vbar(x=data.iloc[:,1], top=data.iloc[:,4], width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = math.pi/2

# %%
show(p)
# Out:
#   <div class="bk-root" id="1e29165f-a4e1-41be-9d22-4dcdcee88d30" data-root-id="1002"></div>

# %% [markdown]
# #Find the top rated books

# %%
data = df[df['Customers_Rated'] > 1000]

# %%
data = data.sort_values(['Rating'],axis=0, ascending=False)[:15]

# %%
data
# Out:
#                                             Book Name  ... Price
# 37  Brijbhoomi Books And Handicrafts® Bhagavad Git...  ...   362
# 22              Sapiens: A Brief History of Humankind  ...   372
# 47  Death; An Inside Story: A book for all those w...  ...   148
# 35           Harry Potter and the Philosopher's Stone  ...   298
# 28                       Grandparents' Bag of Stories  ...   140
# 10  The Almanack Of Naval Ravikant: A Guide to Wea...  ...   195
# 25  Karma: A Yogi's Guide to Crafting Your Destiny...  ...   148
# 1   Atomic Habits: The life-changing million copy ...  ...   482
# 45  Think Like a Monk: The secret of how to harnes...  ...   325
# 41  My Life in Full: Work, Family, and Our Future ...  ...   471
# 32  Indian Polity - For Civil Services and Other S...  ...   608
# 2                             The Psychology of Money  ...   301
# 24  Eat That Frog!: 21 Great Ways to Stop Procrast...  ...   146
# 8   Life's Amazing Secrets: How to Find Balance an...  ...   165
# 3   Ikigai: The Japanese secret to a long and happ...  ...   313
#
# [15 rows x 5 columns]

# %%
p = figure(x_range=data.iloc[:,0], plot_width=800, plot_height=600, title="Top Rated Books with more than 1000 Customers Rating", toolbar_location=None, tools="")

p.vbar(x=data.iloc[:,0], top=data.iloc[:,2], width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = math.pi/2

# %%
show(p)
# Out:
#   <div class="bk-root" id="4cda977a-c8f7-4e0c-9300-7307103be2c8" data-root-id="1080"></div>

# %%
p = figure(x_range=data.iloc[:,1], plot_width=800, plot_height=600, title="Top Rated Books with more than 1000 Customers Rating", toolbar_location=None, tools="")

p.vbar(x=data.iloc[:,1], top=data.iloc[:,2], width=0.9)

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.major_label_orientation = math.pi/2

# %%
show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1019 (DUPLICATE_FACTORS): FactorRange must specify a unique list of categorical factors for an axis: duplicate factors found: 'Sadhguru'
#   <div class="bk-root" id="72afb379-7cd7-455f-8f69-743caa59fc3a" data-root-id="1212"></div>

# %% [markdown]
# #Rating for author and book

# %%
data = df.sort_values(["Customers_Rated"], axis=0, ascending=False)[:20]

# %%
data
# Out:
#                                             Book Name  ... Price
# 12                                      The Alchemist  ...   228
# 16  The Subtle Art of Not Giving a F*ck: A Counter...  ...   325
# 33            How to Win Friends and Influence People  ...    78
# 6   Rich Dad Poor Dad: What the Rich Teach Their K...  ...   302
# 15                The Power of Your Subconscious Mind  ...   125
# 7   My First Library: Boxset of 10 Board Books for...  ...   399
# 22              Sapiens: A Brief History of Humankind  ...   372
# 39  Man's Search For Meaning: The classic tribute ...  ...   237
# 4                                Word Power Made Easy  ...    92
# 35           Harry Potter and the Philosopher's Stone  ...   298
# 23  The Intelligent Investor (English) Paperback –...  ...   485
# 1   Atomic Habits: The life-changing million copy ...  ...   482
# 3   Ikigai: The Japanese secret to a long and happ...  ...   313
# 44                         The Richest Man in Babylon  ...    99
# 2                             The Psychology of Money  ...   301
# 18  Quantitative Aptitude for Competitive Examinat...  ...   469
# 13                           It Ends With Us: A Novel  ...   195
# 45  Think Like a Monk: The secret of how to harnes...  ...   325
# 32  Indian Polity - For Civil Services and Other S...  ...   608
# 29                                  General Knowledge  ...   170
#
# [20 rows x 5 columns]

# %%
from bokeh.transform import factor_cmap
from bokeh.models import Legend
from bokeh.palettes import Dark2_5 as palette
import itertools
from bokeh.palettes import d3
#colors has a list of colors which can be used in plots
colors = itertools.cycle(palette)

palette = d3['Category20'][20]

# %%
index_cmap = factor_cmap('Author', palette=palette,
                         factors=data["Author"])

# %%
p = figure(plot_width=700, plot_height=700, title = "Top Authors: Rating vs. Customers Rated")
p.scatter('Rating','Customers_Rated',source=data,fill_alpha=0.6, fill_color=index_cmap,size=20,legend='Author')
p.xaxis.axis_label = 'RATING'
p.yaxis.axis_label = 'CUSTOMERS RATED'
p.legend.location = 'top_left'
# Out:
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead

# %%
show(p)
# Out:
#   <div class="bk-root" id="63778468-68d3-41a9-95b3-84c0e7a28a09" data-root-id="1309"></div>

# %% [markdown]
# Credit given to Aditya Sharma. From https://www.datacamp.com/community/tutorials/amazon-web-scraping-using-beautifulsoup

# %% [markdown]
# THANK YOU
